# %% [markdown]
# # <center>Data ingestion
# </center>

# %%
import pandas as pd

columns = [
    "index",
    "Lever position (Lp)",
    "Ship speed (V) [knots]",
    "Gas Turbine shaft torque (GTT) [kN/m]",
    "Gas Turbine revolutions (GTn) [rpm]",
    "Gas Generator revolutions (GGn) [rpm]",
    "Starboard Propeller Torque (Ts) [kN/m]",
    "Port Propeller Torque (Tp) [kN/m]",
    "HP Turbine exit temperature (T48) [°C]",
    "Compressor inlet air temperature (T1) [°C]",
    "Compressor outlet air temperature (T2) [°C]",
    "HP Turbine exit pressure (P48) [bar]",
    "Compressor inlet air pressure (P1) [bar]",
    "Compressor outlet air pressure (P2) [bar]",
    "Exhaust gas pressure [bar]",
    "Turbine Injection Control (TIC) [%]",
    "Fuel flow (mf) [kg/s]",
    "Compressor decay coefficient",
    "Turbine decay coefficient"
]

df = pd.read_csv("dataset/data.txt", 
                 sep=r'\s+', 
                 header=None)

df.index = df.index + 1
df.reset_index(inplace=True)
df.columns = columns

# Save to CSV
df.to_csv("turbine_data.csv", index=False)


print("Converted Sensor logs txt (data.txt) --> csv (turbine_data.csv)\n")
print("First 5 rows of Unprocessed data")
print(df.head())
# Out:
# Converted Sensor logs txt (data.txt) --> csv (turbine_data.csv)
#
# First 5 rows of Unprocessed data
#    index  Lever position (Lp)  Ship speed (V) [knots]  \
# 0      1                1.138                     3.0
# 1      2                2.088                     6.0
# 2      3                3.144                     9.0
# 3      4                4.161                    12.0
# 4      5                5.140                    15.0
#
#    Gas Turbine shaft torque (GTT) [kN/m]  Gas Turbine revolutions (GTn) [rpm]  \
# 0                                289.964                             1349.489
# 1                               6960.180                             1376.166
# 2                               8379.229                             1386.757
# 3                              14724.395                             1547.465
# 4                              21636.432                             1924.313
#
#    Gas Generator revolutions (GGn) [rpm]  \
# 0                               6677.380
# 1                               6828.469
# 2                               7111.811
# 3                               7792.630
# 4                               8494.777
#
#    Starboard Propeller Torque (Ts) [kN/m]  Port Propeller Torque (Tp) [kN/m]  \
# 0                                   7.584                              7.584
# 1                                  28.204                             28.204
# 2                                  60.358                             60.358
# 3                                 113.774                            113.774
# 4                                 175.306                            175.306
#
#    HP Turbine exit temperature (T48) [°C]  \
# 0                                 464.006
# 1                                 635.401
# 2                                 606.002
# 3                                 661.471
# 4                                 731.494
#
#    Compressor inlet air temperature (T1) [°C]  \
# 0                                       288.0
# 1                                       288.0
# 2                                       288.0
# 3                                       288.0
# 4                                       288.0
#
#    Compressor outlet air temperature (T2) [°C]  \
# 0                                      550.563
# 1                                      581.658
# 2                                      587.587
# 3                                      613.851
# 4                                      645.642
#
#    HP Turbine exit pressure (P48) [bar]  \
# 0                                 1.096
# 1                                 1.331
# 2                                 1.389
# 3                                 1.658
# 4                                 2.078
#
#    Compressor inlet air pressure (P1) [bar]  \
# 0                                     0.998
# 1                                     0.998
# 2                                     0.998
# 3                                     0.998
# 4                                     0.998
#
#    Compressor outlet air pressure (P2) [bar]  Exhaust gas pressure [bar]  \
# 0                                      5.947                       1.019
# 1                                      7.282                       1.019
# 2                                      7.574                       1.020
# 3                                      9.007                       1.022
# 4                                     11.197                       1.026
#
#    Turbine Injection Control (TIC) [%]  Fuel flow (mf) [kg/s]  \
# 0                                7.137                  0.082
# 1                               10.655                  0.287
# 2                               13.086                  0.259
# 3                               18.109                  0.358
# 4                               26.373                  0.522
#
#    Compressor decay coefficient  Turbine decay coefficient
# 0                          0.95                      0.975
# 1                          0.95                      0.975
# 2                          0.95                      0.975
# 3                          0.95                      0.975
# 4                          0.95                      0.975

# %% [markdown]
# # <center> Data Cleaning & Transformation</center>

# %% [markdown]
# #### Handle nulls, outliers, smoothing

# %%
# Keep first column as integer
df['index'] = df['index'].astype(int)

# Select all other numeric columns exclude index
numeric_cols = df.columns[1:] 

# Fill numeric nulls with median
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# Outlier using (IQR Method)
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower, upper)

# Smoothing values
df[numeric_cols] = df[numeric_cols].rolling(window=3, min_periods=1).mean()

# Round numbers to 2 decimals
df[numeric_cols] = df[numeric_cols].round(2)

print("Cleaned Data")
print(df.head())
# Out:
# Cleaned Data
#    index  Lever position (Lp)  Ship speed (V) [knots]  \
# 0      1                 1.14                     3.0
# 1      2                 1.61                     4.5
# 2      3                 2.12                     6.0
# 3      4                 3.13                     9.0
# 4      5                 4.15                    12.0
#
#    Gas Turbine shaft torque (GTT) [kN/m]  Gas Turbine revolutions (GTn) [rpm]  \
# 0                                 289.96                              1349.49
# 1                                3625.07                              1362.83
# 2                                5209.79                              1370.80
# 3                               10021.27                              1436.80
# 4                               14913.35                              1619.51
#
#    Gas Generator revolutions (GGn) [rpm]  \
# 0                                6677.38
# 1                                6752.92
# 2                                6872.55
# 3                                7244.30
# 4                                7799.74
#
#    Starboard Propeller Torque (Ts) [kN/m]  Port Propeller Torque (Tp) [kN/m]  \
# 0                                    7.58                               7.58
# 1                                   17.89                              17.89
# 2                                   32.05                              32.05
# 3                                   67.45                              67.45
# 4                                  116.48                             116.48
#
#    HP Turbine exit temperature (T48) [°C]  \
# 0                                  464.01
# 1                                  549.70
# 2                                  568.47
# 3                                  634.29
# 4                                  666.32
#
#    Compressor inlet air temperature (T1) [°C]  \
# 0                                       288.0
# 1                                       288.0
# 2                                       288.0
# 3                                       288.0
# 4                                       288.0
#
#    Compressor outlet air temperature (T2) [°C]  \
# 0                                       550.56
# 1                                       566.11
# 2                                       573.27
# 3                                       594.37
# 4                                       615.69
#
#    HP Turbine exit pressure (P48) [bar]  \
# 0                                  1.10
# 1                                  1.21
# 2                                  1.27
# 3                                  1.46
# 4                                  1.71
#
#    Compressor inlet air pressure (P1) [bar]  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    Compressor outlet air pressure (P2) [bar]  Exhaust gas pressure [bar]  \
# 0                                       5.95                        1.02
# 1                                       6.61                        1.02
# 2                                       6.93                        1.02
# 3                                       7.95                        1.02
# 4                                       9.26                        1.02
#
#    Turbine Injection Control (TIC) [%]  Fuel flow (mf) [kg/s]  \
# 0                                 7.14                   0.08
# 1                                 8.90                   0.18
# 2                                10.29                   0.21
# 3                                13.95                   0.30
# 4                                19.19                   0.38
#
#    Compressor decay coefficient  Turbine decay coefficient
# 0                          0.95                       0.98
# 1                          0.95                       0.98
# 2                          0.95                       0.98
# 3                          0.95                       0.98
# 4                          0.95                       0.98

# %% [markdown]
# #### Derived Features : Temp_ratio_T48_T2, Temp_ratio_T1_P1, Torque_diff, RPM_ratio_GTn_GGn, Fuel_per_RPM, Total_Prop_Torque

# %%
import numpy as np
# Temperature-Pressure Ratios
df['Temp_ratio_T48_P48'] = (df['HP Turbine exit temperature (T48) [°C]'] / 
                           df['HP Turbine exit pressure (P48) [bar]']).round(2)
df['Temp_ratio_T1_P1'] = (df['Compressor inlet air temperature (T1) [°C]'] / 
                          df['Compressor inlet air pressure (P1) [bar]']).round(2)
df['Temp_ratio_T2_P2'] =  (df['Compressor outlet air temperature (T2) [°C]'] / 
                          df['Compressor outlet air pressure (P2) [bar]']).round(2)
# Torque Differentials
df['Torque_diff'] = (df['Starboard Propeller Torque (Ts) [kN/m]'] - 
                     df['Port Propeller Torque (Tp) [kN/m]']).round(2)

# Efficiency Indicators
df['RPM_ratio_GTn_GGn'] = (df['Gas Turbine revolutions (GTn) [rpm]'] / 
                           df['Gas Generator revolutions (GGn) [rpm]']).round(2)
df['Fuel_per_RPM'] = (df['Fuel flow (mf) [kg/s]'] / df['Gas Turbine revolutions (GTn) [rpm]']).round(5)

# Total Propeller Torque
df['Total_Prop_Torque'] = (df['Starboard Propeller Torque (Ts) [kN/m]'] +
                            df['Port Propeller Torque (Tp) [kN/m]']).round(2)

angular_velocity_rad_s = df['Gas Turbine revolutions (GTn) [rpm]'] * (2 * np.pi / 60)
df['Power_Proxy_kW'] = (
    df['Gas Turbine shaft torque (GTT) [kN/m]'] * angular_velocity_rad_s
).round(2)

# --- Total Decay Score ---
df['Total_decay_score'] = (
    (1 - df['Compressor decay coefficient']) + (1 - df['Turbine decay coefficient'])
).round(3)

pd.set_option('display.max_columns', None)
print("Cleaned Data with Derived Features")
print(df.head())
# Out:
# Cleaned Data with Derived Features
#    index  Lever position (Lp)  Ship speed (V) [knots]  \
# 0      1                 1.14                     3.0
# 1      2                 1.61                     4.5
# 2      3                 2.12                     6.0
# 3      4                 3.13                     9.0
# 4      5                 4.15                    12.0
#
#    Gas Turbine shaft torque (GTT) [kN/m]  Gas Turbine revolutions (GTn) [rpm]  \
# 0                                 289.96                              1349.49
# 1                                3625.07                              1362.83
# 2                                5209.79                              1370.80
# 3                               10021.27                              1436.80
# 4                               14913.35                              1619.51
#
#    Gas Generator revolutions (GGn) [rpm]  \
# 0                                6677.38
# 1                                6752.92
# 2                                6872.55
# 3                                7244.30
# 4                                7799.74
#
#    Starboard Propeller Torque (Ts) [kN/m]  Port Propeller Torque (Tp) [kN/m]  \
# 0                                    7.58                               7.58
# 1                                   17.89                              17.89
# 2                                   32.05                              32.05
# 3                                   67.45                              67.45
# 4                                  116.48                             116.48
#
#    HP Turbine exit temperature (T48) [°C]  \
# 0                                  464.01
# 1                                  549.70
# 2                                  568.47
# 3                                  634.29
# 4                                  666.32
#
#    Compressor inlet air temperature (T1) [°C]  \
# 0                                       288.0
# 1                                       288.0
# 2                                       288.0
# 3                                       288.0
# 4                                       288.0
#
#    Compressor outlet air temperature (T2) [°C]  \
# 0                                       550.56
# 1                                       566.11
# 2                                       573.27
# 3                                       594.37
# 4                                       615.69
#
#    HP Turbine exit pressure (P48) [bar]  \
# 0                                  1.10
# 1                                  1.21
# 2                                  1.27
# 3                                  1.46
# 4                                  1.71
#
#    Compressor inlet air pressure (P1) [bar]  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    Compressor outlet air pressure (P2) [bar]  Exhaust gas pressure [bar]  \
# 0                                       5.95                        1.02
# 1                                       6.61                        1.02
# 2                                       6.93                        1.02
# 3                                       7.95                        1.02
# 4                                       9.26                        1.02
#
#    Turbine Injection Control (TIC) [%]  Fuel flow (mf) [kg/s]  \
# 0                                 7.14                   0.08
# 1                                 8.90                   0.18
# 2                                10.29                   0.21
# 3                                13.95                   0.30
# 4                                19.19                   0.38
#
#    Compressor decay coefficient  Turbine decay coefficient  \
# 0                          0.95                       0.98
# 1                          0.95                       0.98
# 2                          0.95                       0.98
# 3                          0.95                       0.98
# 4                          0.95                       0.98
#
#    Temp_ratio_T48_P48  Temp_ratio_T1_P1  Temp_ratio_T2_P2  Torque_diff  \
# 0              421.83             288.0             92.53          0.0
# 1              454.30             288.0             85.64          0.0
# 2              447.61             288.0             82.72          0.0
# 3              434.45             288.0             74.76          0.0
# 4              389.66             288.0             66.49          0.0
#
#    RPM_ratio_GTn_GGn  Fuel_per_RPM  Total_Prop_Torque  Power_Proxy_kW  \
# 0               0.20       0.00006              15.16        40976.64
# 1               0.20       0.00013              35.78       517352.68
# 2               0.20       0.00015              64.10       747864.52
# 3               0.20       0.00021             134.90      1507813.75
# 4               0.21       0.00023             232.96      2529224.98
#
#    Total_decay_score
# 0               0.07
# 1               0.07
# 2               0.07
# 3               0.07
# 4               0.07

# %% [markdown]
# #### EDA (Exploratory Data Analysis)
#
# - Summary statistics
# - Null check
# - Correlation heatmap
# - Histograms
# - Boxplots
# - Pair plots

# %%
print("Summary Statistics ")
print(df.describe())
# Out:
# Summary Statistics
#               index  Lever position (Lp)  Ship speed (V) [knots]  \
# count  11934.000000         11934.000000            11934.000000
# mean    5967.500000             5.166026               14.998115
# std     3445.193391             1.852686                5.479262
# min        1.000000             1.140000                3.000000
# 25%     2984.250000             4.150000               12.000000
# 50%     5967.500000             5.160000               15.000000
# 75%     8950.750000             6.210000               18.000000
# max    11934.000000             8.220000               24.000000
#
#        Gas Turbine shaft torque (GTT) [kN/m]  \
# count                           11934.000000
# mean                            27242.126459
# std                             15302.367750
# min                               289.960000
# 25%                             14907.205000
# 50%                             26910.115000
# 75%                             39924.220000
# max                             54257.260000
#
#        Gas Turbine revolutions (GTn) [rpm]  \
# count                         11934.000000
# mean                           2136.117577
# std                             572.999218
# min                            1346.650000
# 25%                            1619.500000
# 50%                            2098.790000
# 75%                            2679.627500
# max                            3108.800000
#
#        Gas Generator revolutions (GGn) [rpm]  \
# count                           11934.000000
# mean                             8200.704791
# std                               812.007975
# min                              6677.380000
# 25%                              7717.715000
# 50%                              8352.050000
# 75%                              8818.260000
# max                              9423.290000
#
#        Starboard Propeller Torque (Ts) [kN/m]  \
# count                            11934.000000
# mean                               227.288493
# std                                137.453525
# min                                  7.580000
# 25%                                116.430000
# 50%                                226.720000
# 75%                                338.830000
# max                                471.900000
#
#        Port Propeller Torque (Tp) [kN/m]  \
# count                       11934.000000
# mean                          227.288493
# std                           137.453525
# min                             7.580000
# 25%                           116.430000
# 50%                           226.720000
# 75%                           338.830000
# max                           471.900000
#
#        HP Turbine exit temperature (T48) [°C]  \
# count                            11934.000000
# mean                               735.453639
# std                                120.528415
# min                                464.010000
# 25%                                636.272500
# 50%                                724.955000
# 75%                                836.335000
# max                                974.220000
#
#        Compressor inlet air temperature (T1) [°C]  \
# count                                     11934.0
# mean                                        288.0
# std                                           0.0
# min                                         288.0
# 25%                                         288.0
# 50%                                         288.0
# 75%                                         288.0
# max                                         288.0
#
#        Compressor outlet air temperature (T2) [°C]  \
# count                                 11934.000000
# mean                                    646.198858
# std                                      51.817547
# min                                     550.560000
# 25%                                     605.080000
# 50%                                     638.750000
# 75%                                     691.110000
# max                                     743.610000
#
#        HP Turbine exit pressure (P48) [bar]  \
# count                          11934.000000
# mean                               2.352919
# std                                0.766799
# min                                1.100000
# 25%                                1.710000
# 50%                                2.330000
# 75%                                3.030000
# max                                3.720000
#
#        Compressor inlet air pressure (P1) [bar]  \
# count                                   11934.0
# mean                                        1.0
# std                                         0.0
# min                                         1.0
# 25%                                         1.0
# 50%                                         1.0
# 75%                                         1.0
# max                                         1.0
#
#        Compressor outlet air pressure (P2) [bar]  Exhaust gas pressure [bar]  \
# count                               11934.000000                11934.000000
# mean                                   12.295921                    1.029996
# std                                     3.802984                    0.008165
# min                                     5.950000                    1.020000
# 25%                                     9.110000                    1.020000
# 50%                                    11.980000                    1.030000
# 75%                                    15.750000                    1.040000
# max                                    19.260000                    1.040000
#
#        Turbine Injection Control (TIC) [%]  Fuel flow (mf) [kg/s]  \
# count                         11934.000000           11934.000000
# mean                             33.626163               0.662464
# std                              17.659270               0.347095
# min                               3.940000               0.080000
# 25%                              17.990000               0.350000
# 50%                              33.790000               0.680000
# 75%                              46.820000               0.930000
# max                              66.400000               1.330000
#
#        Compressor decay coefficient  Turbine decay coefficient  \
# count                  11934.000000               11934.000000
# mean                       0.975093                   0.988033
# std                        0.015260                   0.007762
# min                        0.950000                   0.980000
# 25%                        0.960000                   0.980000
# 50%                        0.980000                   0.990000
# 75%                        0.990000                   0.990000
# max                        1.000000                   1.000000
#
#        Temp_ratio_T48_P48  Temp_ratio_T1_P1  Temp_ratio_T2_P2  Torque_diff  \
# count        11934.000000           11934.0      11934.000000      11934.0
# mean           331.437226             288.0         56.773354          0.0
# std             60.353538               0.0         14.153664          0.0
# min            245.750000             288.0         37.770000          0.0
# 25%            277.760000             288.0         44.060000          0.0
# 50%            311.790000             288.0         52.995000          0.0
# 75%            380.252500             288.0         66.747500          0.0
# max            474.020000             288.0         92.530000          0.0
#
#        RPM_ratio_GTn_GGn  Fuel_per_RPM  Total_Prop_Torque  Power_Proxy_kW  \
# count       11934.000000  11934.000000       11934.000000    1.193400e+04
# mean            0.256652      0.000288         454.576985    7.008479e+06
# std             0.046672      0.000087         274.907049    5.304459e+06
# min             0.200000      0.000060          15.160000    4.097664e+04
# 25%             0.210000      0.000220         232.860000    2.528175e+06
# 50%             0.260000      0.000300         453.440000    5.914256e+06
# 75%             0.300000      0.000350         677.660000    1.125070e+07
# max             0.330000      0.000430         943.800000    1.766261e+07
#
#        Total_decay_score
# count       11934.000000
# mean            0.036874
# std             0.017122
# min             0.000000
# 25%             0.020000
# 50%             0.040000
# 75%             0.050000
# max             0.070000

# %%
print("\nTotal Null Values ")
print(df.isnull().sum())
# Out:
# Total Null Values
# index                                          0
# Lever position (Lp)                            0
# Ship speed (V) [knots]                         0
# Gas Turbine shaft torque (GTT) [kN/m]          0
# Gas Turbine revolutions (GTn) [rpm]            0
# Gas Generator revolutions (GGn) [rpm]          0
# Starboard Propeller Torque (Ts) [kN/m]         0
# Port Propeller Torque (Tp) [kN/m]              0
# HP Turbine exit temperature (T48) [°C]         0
# Compressor inlet air temperature (T1) [°C]     0
# Compressor outlet air temperature (T2) [°C]    0
# HP Turbine exit pressure (P48) [bar]           0
# Compressor inlet air pressure (P1) [bar]       0
# Compressor outlet air pressure (P2) [bar]      0
# Exhaust gas pressure [bar]                     0
# Turbine Injection Control (TIC) [%]            0
# Fuel flow (mf) [kg/s]                          0
# Compressor decay coefficient                   0
# Turbine decay coefficient                      0
# Temp_ratio_T48_P48                             0
# Temp_ratio_T1_P1                               0
# Temp_ratio_T2_P2                               0
# Torque_diff                                    0
# RPM_ratio_GTn_GGn                              0
# Fuel_per_RPM                                   0
# Total_Prop_Torque                              0
# Power_Proxy_kW                                 0
# Total_decay_score                              0
# dtype: int64

# %%
numeric_cols = df.columns[1:]
corr_matrix = df[numeric_cols].corr()
print("\nCorrelation Matrix ")
print(corr_matrix)
# Out:
# Correlation Matrix
#                                              Lever position (Lp)  \
# Lever position (Lp)                                     1.000000
# Ship speed (V) [knots]                                  0.999951
# Gas Turbine shaft torque (GTT) [kN/m]                   0.951117
# Gas Turbine revolutions (GTn) [rpm]                     0.955471
# Gas Generator revolutions (GGn) [rpm]                   0.991875
# Starboard Propeller Torque (Ts) [kN/m]                  0.948370
# Port Propeller Torque (Tp) [kN/m]                       0.948370
# HP Turbine exit temperature (T48) [°C]                  0.958208
# Compressor inlet air temperature (T1) [°C]                   NaN
# Compressor outlet air temperature (T2) [°C]             0.979643
# HP Turbine exit pressure (P48) [bar]                    0.952542
# Compressor inlet air pressure (P1) [bar]                     NaN
# Compressor outlet air pressure (P2) [bar]               0.960738
# Exhaust gas pressure [bar]                              0.897077
# Turbine Injection Control (TIC) [%]                     0.897091
# Fuel flow (mf) [kg/s]                                   0.911544
# Compressor decay coefficient                            0.000563
# Turbine decay coefficient                               0.003229
# Temp_ratio_T48_P48                                     -0.925067
# Temp_ratio_T1_P1                                             NaN
# Temp_ratio_T2_P2                                       -0.939475
# Torque_diff                                                  NaN
# RPM_ratio_GTn_GGn                                       0.890439
# Fuel_per_RPM                                            0.861083
# Total_Prop_Torque                                       0.948370
# Power_Proxy_kW                                          0.932359
# Total_decay_score                                      -0.001966
#
#                                              Ship speed (V) [knots]  \
# Lever position (Lp)                                        0.999951
# Ship speed (V) [knots]                                     1.000000
# Gas Turbine shaft torque (GTT) [kN/m]                      0.948377
# Gas Turbine revolutions (GTn) [rpm]                        0.953231
# Gas Generator revolutions (GGn) [rpm]                      0.992578
# Starboard Propeller Torque (Ts) [kN/m]                     0.945536
# Port Propeller Torque (Tp) [kN/m]                          0.945536
# HP Turbine exit temperature (T48) [°C]                     0.955973
# Compressor inlet air temperature (T1) [°C]                      NaN
# Compressor outlet air temperature (T2) [°C]                0.978055
# HP Turbine exit pressure (P48) [bar]                       0.949939
# Compressor inlet air pressure (P1) [bar]                        NaN
# Compressor outlet air pressure (P2) [bar]                  0.958410
# Exhaust gas pressure [bar]                                 0.894329
# Turbine Injection Control (TIC) [%]                        0.893437
# Fuel flow (mf) [kg/s]                                      0.907932
# Compressor decay coefficient                               0.000566
# Turbine decay coefficient                                  0.003312
# Temp_ratio_T48_P48                                        -0.922540
# Temp_ratio_T1_P1                                                NaN
# Temp_ratio_T2_P2                                          -0.937215
# Torque_diff                                                     NaN
# RPM_ratio_GTn_GGn                                          0.886817
# Fuel_per_RPM                                               0.856735
# Total_Prop_Torque                                          0.945536
# Power_Proxy_kW                                             0.929665
# Total_decay_score                                         -0.002006
#
#                                              Gas Turbine shaft torque (GTT) [kN/m]  \
# Lever position (Lp)                                                       0.951117
# Ship speed (V) [knots]                                                    0.948377
# Gas Turbine shaft torque (GTT) [kN/m]                                     1.000000
# Gas Turbine revolutions (GTn) [rpm]                                       0.996139
# Gas Generator revolutions (GGn) [rpm]                                     0.918770
# Starboard Propeller Torque (Ts) [kN/m]                                    0.999460
# Port Propeller Torque (Tp) [kN/m]                                         0.999460
# HP Turbine exit temperature (T48) [°C]                                    0.990901
# Compressor inlet air temperature (T1) [°C]                                     NaN
# Compressor outlet air temperature (T2) [°C]                               0.988214
# HP Turbine exit pressure (P48) [bar]                                      0.999550
# Compressor inlet air pressure (P1) [bar]                                       NaN
# Compressor outlet air pressure (P2) [bar]                                 0.998429
# Exhaust gas pressure [bar]                                                0.950871
# Turbine Injection Control (TIC) [%]                                       0.980288
# Fuel flow (mf) [kg/s]                                                     0.993302
# Compressor decay coefficient                                              0.004552
# Turbine decay coefficient                                                 0.000946
# Temp_ratio_T48_P48                                                       -0.957794
# Temp_ratio_T1_P1                                                               NaN
# Temp_ratio_T2_P2                                                         -0.961548
# Torque_diff                                                                    NaN
# RPM_ratio_GTn_GGn                                                         0.981903
# Fuel_per_RPM                                                              0.957299
# Total_Prop_Torque                                                         0.999460
# Power_Proxy_kW                                                            0.987793
# Total_decay_score                                                        -0.004486
#
#                                              Gas Turbine revolutions (GTn) [rpm]  \
# Lever position (Lp)                                                     0.955471
# Ship speed (V) [knots]                                                  0.953231
# Gas Turbine shaft torque (GTT) [kN/m]                                   0.996139
# Gas Turbine revolutions (GTn) [rpm]                                     1.000000
# Gas Generator revolutions (GGn) [rpm]                                   0.927351
# Starboard Propeller Torque (Ts) [kN/m]                                  0.995893
# Port Propeller Torque (Tp) [kN/m]                                       0.995893
# HP Turbine exit temperature (T48) [°C]                                  0.986423
# Compressor inlet air temperature (T1) [°C]                                   NaN
# Compressor outlet air temperature (T2) [°C]                             0.989063
# HP Turbine exit pressure (P48) [bar]                                    0.998107
# Compressor inlet air pressure (P1) [bar]                                     NaN
# Compressor outlet air pressure (P2) [bar]                               0.998075
# Exhaust gas pressure [bar]                                              0.960263
# Turbine Injection Control (TIC) [%]                                     0.972824
# Fuel flow (mf) [kg/s]                                                   0.986286
# Compressor decay coefficient                                            0.002088
# Turbine decay coefficient                                               0.000442
# Temp_ratio_T48_P48                                                     -0.959158
# Temp_ratio_T1_P1                                                             NaN
# Temp_ratio_T2_P2                                                       -0.959235
# Torque_diff                                                                  NaN
# RPM_ratio_GTn_GGn                                                       0.983358
# Fuel_per_RPM                                                            0.942820
# Total_Prop_Torque                                                       0.995893
# Power_Proxy_kW                                                          0.984634
# Total_decay_score                                                      -0.002061
#
#                                              Gas Generator revolutions (GGn) [rpm]  \
# Lever position (Lp)                                                       0.991875
# Ship speed (V) [knots]                                                    0.992578
# Gas Turbine shaft torque (GTT) [kN/m]                                     0.918770
# Gas Turbine revolutions (GTn) [rpm]                                       0.927351
# Gas Generator revolutions (GGn) [rpm]                                     1.000000
# Starboard Propeller Torque (Ts) [kN/m]                                    0.914920
# Port Propeller Torque (Tp) [kN/m]                                         0.914920
# HP Turbine exit temperature (T48) [°C]                                    0.933088
# Compressor inlet air temperature (T1) [°C]                                     NaN
# Compressor outlet air temperature (T2) [°C]                               0.960834
# HP Turbine exit pressure (P48) [bar]                                      0.921157
# Compressor inlet air pressure (P1) [bar]                                       NaN
# Compressor outlet air pressure (P2) [bar]                                 0.931755
# Exhaust gas pressure [bar]                                                0.874275
# Turbine Injection Control (TIC) [%]                                       0.856750
# Fuel flow (mf) [kg/s]                                                     0.871192
# Compressor decay coefficient                                             -0.024378
# Turbine decay coefficient                                                 0.015688
# Temp_ratio_T48_P48                                                       -0.913665
# Temp_ratio_T1_P1                                                               NaN
# Temp_ratio_T2_P2                                                         -0.930980
# Torque_diff                                                                    NaN
# RPM_ratio_GTn_GGn                                                         0.851014
# Fuel_per_RPM                                                              0.830843
# Total_Prop_Torque                                                         0.914920
# Power_Proxy_kW                                                            0.888424
# Total_decay_score                                                         0.014614
#
#                                              Starboard Propeller Torque (Ts) [kN/m]  \
# Lever position (Lp)                                                        0.948370
# Ship speed (V) [knots]                                                     0.945536
# Gas Turbine shaft torque (GTT) [kN/m]                                      0.999460
# Gas Turbine revolutions (GTn) [rpm]                                        0.995893
# Gas Generator revolutions (GGn) [rpm]                                      0.914920
# Starboard Propeller Torque (Ts) [kN/m]                                     1.000000
# Port Propeller Torque (Tp) [kN/m]                                          1.000000
# HP Turbine exit temperature (T48) [°C]                                     0.987334
# Compressor inlet air temperature (T1) [°C]                                      NaN
# Compressor outlet air temperature (T2) [°C]                                0.986106
# HP Turbine exit pressure (P48) [bar]                                       0.999128
# Compressor inlet air pressure (P1) [bar]                                        NaN
# Compressor outlet air pressure (P2) [bar]                                  0.997574
# Exhaust gas pressure [bar]                                                 0.949639
# Turbine Injection Control (TIC) [%]                                        0.980917
# Fuel flow (mf) [kg/s]                                                      0.993395
# Compressor decay coefficient                                               0.001429
# Turbine decay coefficient                                                  0.000371
# Temp_ratio_T48_P48                                                        -0.958880
# Temp_ratio_T1_P1                                                                NaN
# Temp_ratio_T2_P2                                                          -0.959388
# Torque_diff                                                                     NaN
# RPM_ratio_GTn_GGn                                                          0.983162
# Fuel_per_RPM                                                               0.955864
# Total_Prop_Torque                                                          1.000000
# Power_Proxy_kW                                                             0.988327
# Total_decay_score                                                         -0.001442
#
#                                              Port Propeller Torque (Tp) [kN/m]  \
# Lever position (Lp)                                                   0.948370
# Ship speed (V) [knots]                                                0.945536
# Gas Turbine shaft torque (GTT) [kN/m]                                 0.999460
# Gas Turbine revolutions (GTn) [rpm]                                   0.995893
# Gas Generator revolutions (GGn) [rpm]                                 0.914920
# Starboard Propeller Torque (Ts) [kN/m]                                1.000000
# Port Propeller Torque (Tp) [kN/m]                                     1.000000
# HP Turbine exit temperature (T48) [°C]                                0.987334
# Compressor inlet air temperature (T1) [°C]                                 NaN
# Compressor outlet air temperature (T2) [°C]                           0.986106
# HP Turbine exit pressure (P48) [bar]                                  0.999128
# Compressor inlet air pressure (P1) [bar]                                   NaN
# Compressor outlet air pressure (P2) [bar]                             0.997574
# Exhaust gas pressure [bar]                                            0.949639
# Turbine Injection Control (TIC) [%]                                   0.980917
# Fuel flow (mf) [kg/s]                                                 0.993395
# Compressor decay coefficient                                          0.001429
# Turbine decay coefficient                                             0.000371
# Temp_ratio_T48_P48                                                   -0.958880
# Temp_ratio_T1_P1                                                           NaN
# Temp_ratio_T2_P2                                                     -0.959388
# Torque_diff                                                                NaN
# RPM_ratio_GTn_GGn                                                     0.983162
# Fuel_per_RPM                                                          0.955864
# Total_Prop_Torque                                                     1.000000
# Power_Proxy_kW                                                        0.988327
# Total_decay_score                                                    -0.001442
#
#                                              HP Turbine exit temperature (T48) [°C]  \
# Lever position (Lp)                                                        0.958208
# Ship speed (V) [knots]                                                     0.955973
# Gas Turbine shaft torque (GTT) [kN/m]                                      0.990901
# Gas Turbine revolutions (GTn) [rpm]                                        0.986423
# Gas Generator revolutions (GGn) [rpm]                                      0.933088
# Starboard Propeller Torque (Ts) [kN/m]                                     0.987334
# Port Propeller Torque (Tp) [kN/m]                                          0.987334
# HP Turbine exit temperature (T48) [°C]                                     1.000000
# Compressor inlet air temperature (T1) [°C]                                      NaN
# Compressor outlet air temperature (T2) [°C]                                0.993907
# HP Turbine exit pressure (P48) [bar]                                       0.989722
# Compressor inlet air pressure (P1) [bar]                                        NaN
# Compressor outlet air pressure (P2) [bar]                                  0.991921
# Exhaust gas pressure [bar]                                                 0.942068
# Turbine Injection Control (TIC) [%]                                        0.970228
# Fuel flow (mf) [kg/s]                                                      0.982638
# Compressor decay coefficient                                              -0.055816
# Turbine decay coefficient                                                 -0.049672
# Temp_ratio_T48_P48                                                        -0.940680
# Temp_ratio_T1_P1                                                                NaN
# Temp_ratio_T2_P2                                                          -0.961080
# Torque_diff                                                                     NaN
# RPM_ratio_GTn_GGn                                                          0.963027
# Fuel_per_RPM                                                               0.954030
# Total_Prop_Torque                                                          0.987334
# Power_Proxy_kW                                                             0.973927
# Total_decay_score                                                          0.072261
#
#                                              Compressor inlet air temperature (T1) [°C]  \
# Lever position (Lp)                                                                 NaN
# Ship speed (V) [knots]                                                              NaN
# Gas Turbine shaft torque (GTT) [kN/m]                                               NaN
# Gas Turbine revolutions (GTn) [rpm]                                                 NaN
# Gas Generator revolutions (GGn) [rpm]                                               NaN
# Starboard Propeller Torque (Ts) [kN/m]                                              NaN
# Port Propeller Torque (Tp) [kN/m]                                                   NaN
# HP Turbine exit temperature (T48) [°C]                                              NaN
# Compressor inlet air temperature (T1) [°C]                                          NaN
# Compressor outlet air temperature (T2) [°C]                                         NaN
# HP Turbine exit pressure (P48) [bar]                                                NaN
# Compressor inlet air pressure (P1) [bar]                                            NaN
# Compressor outlet air pressure (P2) [bar]                                           NaN
# Exhaust gas pressure [bar]                                                          NaN
# Turbine Injection Control (TIC) [%]                                                 NaN
# Fuel flow (mf) [kg/s]                                                               NaN
# Compressor decay coefficient                                                        NaN
# Turbine decay coefficient                                                           NaN
# Temp_ratio_T48_P48                                                                  NaN
# Temp_ratio_T1_P1                                                                    NaN
# Temp_ratio_T2_P2                                                                    NaN
# Torque_diff                                                                         NaN
# RPM_ratio_GTn_GGn                                                                   NaN
# Fuel_per_RPM                                                                        NaN
# Total_Prop_Torque                                                                   NaN
# Power_Proxy_kW                                                                      NaN
# Total_decay_score                                                                   NaN
#
#                                              Compressor outlet air temperature (T2) [°C]  \
# Lever position (Lp)                                                             0.979643
# Ship speed (V) [knots]                                                          0.978055
# Gas Turbine shaft torque (GTT) [kN/m]                                           0.988214
# Gas Turbine revolutions (GTn) [rpm]                                             0.989063
# Gas Generator revolutions (GGn) [rpm]                                           0.960834
# Starboard Propeller Torque (Ts) [kN/m]                                          0.986106
# Port Propeller Torque (Tp) [kN/m]                                               0.986106
# HP Turbine exit temperature (T48) [°C]                                          0.993907
# Compressor inlet air temperature (T1) [°C]                                           NaN
# Compressor outlet air temperature (T2) [°C]                                     1.000000
# HP Turbine exit pressure (P48) [bar]                                            0.988445
# Compressor inlet air pressure (P1) [bar]                                             NaN
# Compressor outlet air pressure (P2) [bar]                                       0.991973
# Exhaust gas pressure [bar]                                                      0.943529
# Turbine Injection Control (TIC) [%]                                             0.957282
# Fuel flow (mf) [kg/s]                                                           0.970223
# Compressor decay coefficient                                                   -0.064636
# Turbine decay coefficient                                                      -0.020147
# Temp_ratio_T48_P48                                                             -0.949064
# Temp_ratio_T1_P1                                                                     NaN
# Temp_ratio_T2_P2                                                               -0.962921
# Torque_diff                                                                          NaN
# RPM_ratio_GTn_GGn                                                               0.954112
# Fuel_per_RPM                                                                    0.932046
# Total_Prop_Torque                                                               0.986106
# Power_Proxy_kW                                                                  0.970752
# Total_decay_score                                                               0.066737
#
#                                              HP Turbine exit pressure (P48) [bar]  \
# Lever position (Lp)                                                      0.952542
# Ship speed (V) [knots]                                                   0.949939
# Gas Turbine shaft torque (GTT) [kN/m]                                    0.999550
# Gas Turbine revolutions (GTn) [rpm]                                      0.998107
# Gas Generator revolutions (GGn) [rpm]                                    0.921157
# Starboard Propeller Torque (Ts) [kN/m]                                   0.999128
# Port Propeller Torque (Tp) [kN/m]                                        0.999128
# HP Turbine exit temperature (T48) [°C]                                   0.989722
# Compressor inlet air temperature (T1) [°C]                                    NaN
# Compressor outlet air temperature (T2) [°C]                              0.988445
# HP Turbine exit pressure (P48) [bar]                                     1.000000
# Compressor inlet air pressure (P1) [bar]                                      NaN
# Compressor outlet air pressure (P2) [bar]                                0.999248
# Exhaust gas pressure [bar]                                               0.954732
# Turbine Injection Control (TIC) [%]                                      0.979002
# Fuel flow (mf) [kg/s]                                                    0.991978
# Compressor decay coefficient                                             0.011558
# Turbine decay coefficient                                               -0.003007
# Temp_ratio_T48_P48                                                      -0.959283
# Temp_ratio_T1_P1                                                              NaN
# Temp_ratio_T2_P2                                                        -0.961635
# Torque_diff                                                                   NaN
# RPM_ratio_GTn_GGn                                                        0.983490
# Fuel_per_RPM                                                             0.953554
# Total_Prop_Torque                                                        0.999128
# Power_Proxy_kW                                                           0.987633
# Total_decay_score                                                       -0.008937
#
#                                              Compressor inlet air pressure (P1) [bar]  \
# Lever position (Lp)                                                               NaN
# Ship speed (V) [knots]                                                            NaN
# Gas Turbine shaft torque (GTT) [kN/m]                                             NaN
# Gas Turbine revolutions (GTn) [rpm]                                               NaN
# Gas Generator revolutions (GGn) [rpm]                                             NaN
# Starboard Propeller Torque (Ts) [kN/m]                                            NaN
# Port Propeller Torque (Tp) [kN/m]                                                 NaN
# HP Turbine exit temperature (T48) [°C]                                            NaN
# Compressor inlet air temperature (T1) [°C]                                        NaN
# Compressor outlet air temperature (T2) [°C]                                       NaN
# HP Turbine exit pressure (P48) [bar]                                              NaN
# Compressor inlet air pressure (P1) [bar]                                          NaN
# Compressor outlet air pressure (P2) [bar]                                         NaN
# Exhaust gas pressure [bar]                                                        NaN
# Turbine Injection Control (TIC) [%]                                               NaN
# Fuel flow (mf) [kg/s]                                                             NaN
# Compressor decay coefficient                                                      NaN
# Turbine decay coefficient                                                         NaN
# Temp_ratio_T48_P48                                                                NaN
# Temp_ratio_T1_P1                                                                  NaN
# Temp_ratio_T2_P2                                                                  NaN
# Torque_diff                                                                       NaN
# RPM_ratio_GTn_GGn                                                                 NaN
# Fuel_per_RPM                                                                      NaN
# Total_Prop_Torque                                                                 NaN
# Power_Proxy_kW                                                                    NaN
# Total_decay_score                                                                 NaN
#
#                                              Compressor outlet air pressure (P2) [bar]  \
# Lever position (Lp)                                                           0.960738
# Ship speed (V) [knots]                                                        0.958410
# Gas Turbine shaft torque (GTT) [kN/m]                                         0.998429
# Gas Turbine revolutions (GTn) [rpm]                                           0.998075
# Gas Generator revolutions (GGn) [rpm]                                         0.931755
# Starboard Propeller Torque (Ts) [kN/m]                                        0.997574
# Port Propeller Torque (Tp) [kN/m]                                             0.997574
# HP Turbine exit temperature (T48) [°C]                                        0.991921
# Compressor inlet air temperature (T1) [°C]                                         NaN
# Compressor outlet air temperature (T2) [°C]                                   0.991973
# HP Turbine exit pressure (P48) [bar]                                          0.999248
# Compressor inlet air pressure (P1) [bar]                                           NaN
# Compressor outlet air pressure (P2) [bar]                                     1.000000
# Exhaust gas pressure [bar]                                                    0.953981
# Turbine Injection Control (TIC) [%]                                           0.975005
# Fuel flow (mf) [kg/s]                                                         0.988260
# Compressor decay coefficient                                                  0.011788
# Turbine decay coefficient                                                    -0.022604
# Temp_ratio_T48_P48                                                           -0.958722
# Temp_ratio_T1_P1                                                                   NaN
# Temp_ratio_T2_P2                                                             -0.963958
# Torque_diff                                                                        NaN
# RPM_ratio_GTn_GGn                                                             0.978506
# Fuel_per_RPM                                                                  0.948983
# Total_Prop_Torque                                                             0.997574
# Power_Proxy_kW                                                                0.985523
# Total_decay_score                                                            -0.000259
#
#                                              Exhaust gas pressure [bar]  \
# Lever position (Lp)                                            0.897077
# Ship speed (V) [knots]                                         0.894329
# Gas Turbine shaft torque (GTT) [kN/m]                          0.950871
# Gas Turbine revolutions (GTn) [rpm]                            0.960263
# Gas Generator revolutions (GGn) [rpm]                          0.874275
# Starboard Propeller Torque (Ts) [kN/m]                         0.949639
# Port Propeller Torque (Tp) [kN/m]                              0.949639
# HP Turbine exit temperature (T48) [°C]                         0.942068
# Compressor inlet air temperature (T1) [°C]                          NaN
# Compressor outlet air temperature (T2) [°C]                    0.943529
# HP Turbine exit pressure (P48) [bar]                           0.954732
# Compressor inlet air pressure (P1) [bar]                            NaN
# Compressor outlet air pressure (P2) [bar]                      0.953981
# Exhaust gas pressure [bar]                                     1.000000
# Turbine Injection Control (TIC) [%]                            0.936065
# Fuel flow (mf) [kg/s]                                          0.946381
# Compressor decay coefficient                                   0.000642
# Turbine decay coefficient                                      0.000399
# Temp_ratio_T48_P48                                            -0.938252
# Temp_ratio_T1_P1                                                    NaN
# Temp_ratio_T2_P2                                              -0.935748
# Torque_diff                                                         NaN
# RPM_ratio_GTn_GGn                                              0.962238
# Fuel_per_RPM                                                   0.921020
# Total_Prop_Torque                                              0.949639
# Power_Proxy_kW                                                 0.925035
# Total_decay_score                                             -0.000753
#
#                                              Turbine Injection Control (TIC) [%]  \
# Lever position (Lp)                                                     0.897091
# Ship speed (V) [knots]                                                  0.893437
# Gas Turbine shaft torque (GTT) [kN/m]                                   0.980288
# Gas Turbine revolutions (GTn) [rpm]                                     0.972824
# Gas Generator revolutions (GGn) [rpm]                                   0.856750
# Starboard Propeller Torque (Ts) [kN/m]                                  0.980917
# Port Propeller Torque (Tp) [kN/m]                                       0.980917
# HP Turbine exit temperature (T48) [°C]                                  0.970228
# Compressor inlet air temperature (T1) [°C]                                   NaN
# Compressor outlet air temperature (T2) [°C]                             0.957282
# HP Turbine exit pressure (P48) [bar]                                    0.979002
# Compressor inlet air pressure (P1) [bar]                                     NaN
# Compressor outlet air pressure (P2) [bar]                               0.975005
# Exhaust gas pressure [bar]                                              0.936065
# Turbine Injection Control (TIC) [%]                                     1.000000
# Fuel flow (mf) [kg/s]                                                   0.989683
# Compressor decay coefficient                                           -0.043825
# Turbine decay coefficient                                              -0.024767
# Temp_ratio_T48_P48                                                     -0.927092
# Temp_ratio_T1_P1                                                             NaN
# Temp_ratio_T2_P2                                                       -0.930752
# Torque_diff                                                                  NaN
# RPM_ratio_GTn_GGn                                                       0.980316
# Fuel_per_RPM                                                            0.963293
# Total_Prop_Torque                                                       0.980917
# Power_Proxy_kW                                                          0.971661
# Total_decay_score                                                       0.050284
#
#                                              Fuel flow (mf) [kg/s]  \
# Lever position (Lp)                                       0.911544
# Ship speed (V) [knots]                                    0.907932
# Gas Turbine shaft torque (GTT) [kN/m]                     0.993302
# Gas Turbine revolutions (GTn) [rpm]                       0.986286
# Gas Generator revolutions (GGn) [rpm]                     0.871192
# Starboard Propeller Torque (Ts) [kN/m]                    0.993395
# Port Propeller Torque (Tp) [kN/m]                         0.993395
# HP Turbine exit temperature (T48) [°C]                    0.982638
# Compressor inlet air temperature (T1) [°C]                     NaN
# Compressor outlet air temperature (T2) [°C]               0.970223
# HP Turbine exit pressure (P48) [bar]                      0.991978
# Compressor inlet air pressure (P1) [bar]                       NaN
# Compressor outlet air pressure (P2) [bar]                 0.988260
# Exhaust gas pressure [bar]                                0.946381
# Turbine Injection Control (TIC) [%]                       0.989683
# Fuel flow (mf) [kg/s]                                     1.000000
# Compressor decay coefficient                             -0.019371
# Turbine decay coefficient                                -0.023409
# Temp_ratio_T48_P48                                       -0.941620
# Temp_ratio_T1_P1                                               NaN
# Temp_ratio_T2_P2                                         -0.944962
# Torque_diff                                                    NaN
# RPM_ratio_GTn_GGn                                         0.990175
# Fuel_per_RPM                                              0.970509
# Total_Prop_Torque                                         0.993395
# Power_Proxy_kW                                            0.984304
# Total_decay_score                                         0.027876
#
#                                              Compressor decay coefficient  \
# Lever position (Lp)                                              0.000563
# Ship speed (V) [knots]                                           0.000566
# Gas Turbine shaft torque (GTT) [kN/m]                            0.004552
# Gas Turbine revolutions (GTn) [rpm]                              0.002088
# Gas Generator revolutions (GGn) [rpm]                           -0.024378
# Starboard Propeller Torque (Ts) [kN/m]                           0.001429
# Port Propeller Torque (Tp) [kN/m]                                0.001429
# HP Turbine exit temperature (T48) [°C]                          -0.055816
# Compressor inlet air temperature (T1) [°C]                            NaN
# Compressor outlet air temperature (T2) [°C]                     -0.064636
# HP Turbine exit pressure (P48) [bar]                             0.011558
# Compressor inlet air pressure (P1) [bar]                              NaN
# Compressor outlet air pressure (P2) [bar]                        0.011788
# Exhaust gas pressure [bar]                                       0.000642
# Turbine Injection Control (TIC) [%]                             -0.043825
# Fuel flow (mf) [kg/s]                                           -0.019371
# Compressor decay coefficient                                     1.000000
# Turbine decay coefficient                                        0.000306
# Temp_ratio_T48_P48                                              -0.067532
# Temp_ratio_T1_P1                                                      NaN
# Temp_ratio_T2_P2                                                -0.036060
# Torque_diff                                                           NaN
# RPM_ratio_GTn_GGn                                                0.000296
# Fuel_per_RPM                                                    -0.032697
# Total_Prop_Torque                                                0.001429
# Power_Proxy_kW                                                   0.002762
# Total_decay_score                                               -0.891346
#
#                                              Turbine decay coefficient  \
# Lever position (Lp)                                           0.003229
# Ship speed (V) [knots]                                        0.003312
# Gas Turbine shaft torque (GTT) [kN/m]                         0.000946
# Gas Turbine revolutions (GTn) [rpm]                           0.000442
# Gas Generator revolutions (GGn) [rpm]                         0.015688
# Starboard Propeller Torque (Ts) [kN/m]                        0.000371
# Port Propeller Torque (Tp) [kN/m]                             0.000371
# HP Turbine exit temperature (T48) [°C]                       -0.049672
# Compressor inlet air temperature (T1) [°C]                         NaN
# Compressor outlet air temperature (T2) [°C]                  -0.020147
# HP Turbine exit pressure (P48) [bar]                         -0.003007
# Compressor inlet air pressure (P1) [bar]                           NaN
# Compressor outlet air pressure (P2) [bar]                    -0.022604
# Exhaust gas pressure [bar]                                    0.000399
# Turbine Injection Control (TIC) [%]                          -0.024767
# Fuel flow (mf) [kg/s]                                        -0.023409
# Compressor decay coefficient                                  0.000306
# Turbine decay coefficient                                     1.000000
# Temp_ratio_T48_P48                                           -0.040066
# Temp_ratio_T1_P1                                                   NaN
# Temp_ratio_T2_P2                                              0.021849
# Torque_diff                                                        NaN
# RPM_ratio_GTn_GGn                                            -0.001362
# Fuel_per_RPM                                                 -0.041527
# Total_Prop_Torque                                             0.000371
# Power_Proxy_kW                                                0.001484
# Total_decay_score                                            -0.453597
#
#                                              Temp_ratio_T48_P48  \
# Lever position (Lp)                                   -0.925067
# Ship speed (V) [knots]                                -0.922540
# Gas Turbine shaft torque (GTT) [kN/m]                 -0.957794
# Gas Turbine revolutions (GTn) [rpm]                   -0.959158
# Gas Generator revolutions (GGn) [rpm]                 -0.913665
# Starboard Propeller Torque (Ts) [kN/m]                -0.958880
# Port Propeller Torque (Tp) [kN/m]                     -0.958880
# HP Turbine exit temperature (T48) [°C]                -0.940680
# Compressor inlet air temperature (T1) [°C]                  NaN
# Compressor outlet air temperature (T2) [°C]           -0.949064
# HP Turbine exit pressure (P48) [bar]                  -0.959283
# Compressor inlet air pressure (P1) [bar]                    NaN
# Compressor outlet air pressure (P2) [bar]             -0.958722
# Exhaust gas pressure [bar]                            -0.938252
# Turbine Injection Control (TIC) [%]                   -0.927092
# Fuel flow (mf) [kg/s]                                 -0.941620
# Compressor decay coefficient                          -0.067532
# Turbine decay coefficient                             -0.040066
# Temp_ratio_T48_P48                                     1.000000
# Temp_ratio_T1_P1                                            NaN
# Temp_ratio_T2_P2                                       0.990153
# Torque_diff                                                 NaN
# RPM_ratio_GTn_GGn                                     -0.949587
# Fuel_per_RPM                                          -0.950217
# Total_Prop_Torque                                     -0.958880
# Power_Proxy_kW                                        -0.908141
# Total_decay_score                                      0.078348
#
#                                              Temp_ratio_T1_P1  \
# Lever position (Lp)                                       NaN
# Ship speed (V) [knots]                                    NaN
# Gas Turbine shaft torque (GTT) [kN/m]                     NaN
# Gas Turbine revolutions (GTn) [rpm]                       NaN
# Gas Generator revolutions (GGn) [rpm]                     NaN
# Starboard Propeller Torque (Ts) [kN/m]                    NaN
# Port Propeller Torque (Tp) [kN/m]                         NaN
# HP Turbine exit temperature (T48) [°C]                    NaN
# Compressor inlet air temperature (T1) [°C]                NaN
# Compressor outlet air temperature (T2) [°C]               NaN
# HP Turbine exit pressure (P48) [bar]                      NaN
# Compressor inlet air pressure (P1) [bar]                  NaN
# Compressor outlet air pressure (P2) [bar]                 NaN
# Exhaust gas pressure [bar]                                NaN
# Turbine Injection Control (TIC) [%]                       NaN
# Fuel flow (mf) [kg/s]                                     NaN
# Compressor decay coefficient                              NaN
# Turbine decay coefficient                                 NaN
# Temp_ratio_T48_P48                                        NaN
# Temp_ratio_T1_P1                                          NaN
# Temp_ratio_T2_P2                                          NaN
# Torque_diff                                               NaN
# RPM_ratio_GTn_GGn                                         NaN
# Fuel_per_RPM                                              NaN
# Total_Prop_Torque                                         NaN
# Power_Proxy_kW                                            NaN
# Total_decay_score                                         NaN
#
#                                              Temp_ratio_T2_P2  Torque_diff  \
# Lever position (Lp)                                 -0.939475          NaN
# Ship speed (V) [knots]                              -0.937215          NaN
# Gas Turbine shaft torque (GTT) [kN/m]               -0.961548          NaN
# Gas Turbine revolutions (GTn) [rpm]                 -0.959235          NaN
# Gas Generator revolutions (GGn) [rpm]               -0.930980          NaN
# Starboard Propeller Torque (Ts) [kN/m]              -0.959388          NaN
# Port Propeller Torque (Tp) [kN/m]                   -0.959388          NaN
# HP Turbine exit temperature (T48) [°C]              -0.961080          NaN
# Compressor inlet air temperature (T1) [°C]                NaN          NaN
# Compressor outlet air temperature (T2) [°C]         -0.962921          NaN
# HP Turbine exit pressure (P48) [bar]                -0.961635          NaN
# Compressor inlet air pressure (P1) [bar]                  NaN          NaN
# Compressor outlet air pressure (P2) [bar]           -0.963958          NaN
# Exhaust gas pressure [bar]                          -0.935748          NaN
# Turbine Injection Control (TIC) [%]                 -0.930752          NaN
# Fuel flow (mf) [kg/s]                               -0.944962          NaN
# Compressor decay coefficient                        -0.036060          NaN
# Turbine decay coefficient                            0.021849          NaN
# Temp_ratio_T48_P48                                   0.990153          NaN
# Temp_ratio_T1_P1                                          NaN          NaN
# Temp_ratio_T2_P2                                     1.000000          NaN
# Torque_diff                                               NaN          NaN
# RPM_ratio_GTn_GGn                                   -0.942012          NaN
# Fuel_per_RPM                                        -0.962275          NaN
# Total_Prop_Torque                                   -0.959388          NaN
# Power_Proxy_kW                                      -0.908366          NaN
# Total_decay_score                                    0.022232          NaN
#
#                                              RPM_ratio_GTn_GGn  Fuel_per_RPM  \
# Lever position (Lp)                                   0.890439      0.861083
# Ship speed (V) [knots]                                0.886817      0.856735
# Gas Turbine shaft torque (GTT) [kN/m]                 0.981903      0.957299
# Gas Turbine revolutions (GTn) [rpm]                   0.983358      0.942820
# Gas Generator revolutions (GGn) [rpm]                 0.851014      0.830843
# Starboard Propeller Torque (Ts) [kN/m]                0.983162      0.955864
# Port Propeller Torque (Tp) [kN/m]                     0.983162      0.955864
# HP Turbine exit temperature (T48) [°C]                0.963027      0.954030
# Compressor inlet air temperature (T1) [°C]                 NaN           NaN
# Compressor outlet air temperature (T2) [°C]           0.954112      0.932046
# HP Turbine exit pressure (P48) [bar]                  0.983490      0.953554
# Compressor inlet air pressure (P1) [bar]                   NaN           NaN
# Compressor outlet air pressure (P2) [bar]             0.978506      0.948983
# Exhaust gas pressure [bar]                            0.962238      0.921020
# Turbine Injection Control (TIC) [%]                   0.980316      0.963293
# Fuel flow (mf) [kg/s]                                 0.990175      0.970509
# Compressor decay coefficient                          0.000296     -0.032697
# Turbine decay coefficient                            -0.001362     -0.041527
# Temp_ratio_T48_P48                                   -0.949587     -0.950217
# Temp_ratio_T1_P1                                           NaN           NaN
# Temp_ratio_T2_P2                                     -0.942012     -0.962275
# Torque_diff                                                NaN           NaN
# RPM_ratio_GTn_GGn                                     1.000000      0.963369
# Fuel_per_RPM                                          0.963369      1.000000
# Total_Prop_Torque                                     0.983162      0.955864
# Power_Proxy_kW                                        0.968655      0.916234
# Total_decay_score                                     0.000353      0.047965
#
#                                              Total_Prop_Torque  \
# Lever position (Lp)                                   0.948370
# Ship speed (V) [knots]                                0.945536
# Gas Turbine shaft torque (GTT) [kN/m]                 0.999460
# Gas Turbine revolutions (GTn) [rpm]                   0.995893
# Gas Generator revolutions (GGn) [rpm]                 0.914920
# Starboard Propeller Torque (Ts) [kN/m]                1.000000
# Port Propeller Torque (Tp) [kN/m]                     1.000000
# HP Turbine exit temperature (T48) [°C]                0.987334
# Compressor inlet air temperature (T1) [°C]                 NaN
# Compressor outlet air temperature (T2) [°C]           0.986106
# HP Turbine exit pressure (P48) [bar]                  0.999128
# Compressor inlet air pressure (P1) [bar]                   NaN
# Compressor outlet air pressure (P2) [bar]             0.997574
# Exhaust gas pressure [bar]                            0.949639
# Turbine Injection Control (TIC) [%]                   0.980917
# Fuel flow (mf) [kg/s]                                 0.993395
# Compressor decay coefficient                          0.001429
# Turbine decay coefficient                             0.000371
# Temp_ratio_T48_P48                                   -0.958880
# Temp_ratio_T1_P1                                           NaN
# Temp_ratio_T2_P2                                     -0.959388
# Torque_diff                                                NaN
# RPM_ratio_GTn_GGn                                     0.983162
# Fuel_per_RPM                                          0.955864
# Total_Prop_Torque                                     1.000000
# Power_Proxy_kW                                        0.988327
# Total_decay_score                                    -0.001442
#
#                                              Power_Proxy_kW  Total_decay_score
# Lever position (Lp)                                0.932359          -0.001966
# Ship speed (V) [knots]                             0.929665          -0.002006
# Gas Turbine shaft torque (GTT) [kN/m]              0.987793          -0.004486
# Gas Turbine revolutions (GTn) [rpm]                0.984634          -0.002061
# Gas Generator revolutions (GGn) [rpm]              0.888424           0.014614
# Starboard Propeller Torque (Ts) [kN/m]             0.988327          -0.001442
# Port Propeller Torque (Tp) [kN/m]                  0.988327          -0.001442
# HP Turbine exit temperature (T48) [°C]             0.973927           0.072261
# Compressor inlet air temperature (T1) [°C]              NaN                NaN
# Compressor outlet air temperature (T2) [°C]        0.970752           0.066737
# HP Turbine exit pressure (P48) [bar]               0.987633          -0.008937
# Compressor inlet air pressure (P1) [bar]                NaN                NaN
# Compressor outlet air pressure (P2) [bar]          0.985523          -0.000259
# Exhaust gas pressure [bar]                         0.925035          -0.000753
# Turbine Injection Control (TIC) [%]                0.971661           0.050284
# Fuel flow (mf) [kg/s]                              0.984304           0.027876
# Compressor decay coefficient                       0.002762          -0.891346
# Turbine decay coefficient                          0.001484          -0.453597
# Temp_ratio_T48_P48                                -0.908141           0.078348
# Temp_ratio_T1_P1                                        NaN                NaN
# Temp_ratio_T2_P2                                  -0.908366           0.022232
# Torque_diff                                             NaN                NaN
# RPM_ratio_GTn_GGn                                  0.968655           0.000353
# Fuel_per_RPM                                       0.916234           0.047965
# Total_Prop_Torque                                  0.988327          -0.001442
# Power_Proxy_kW                                     1.000000          -0.003134
# Total_decay_score                                 -0.003134           1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap of Turbine Features")
plt.show()

# %%
#Distributions of Key Columns
key_cols = ['HP Turbine exit temperature (T48) [°C]',
            'Compressor outlet air temperature (T2) [°C]',
            'Fuel flow (mf) [kg/s]',
            'Starboard Propeller Torque (Ts) [kN/m]',
            'Port Propeller Torque (Tp) [kN/m]',
            'Torque_diff',
            'Temp_ratio_T48_P48']

for col in key_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], bins=20, kde=True, color='skyblue')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
#Boxplots to detect remaining outliers
for col in key_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
#Pairwise relationship
sns.pairplot(df[['Torque_diff', 'Total_Prop_Torque', 'Fuel_per_RPM', 'RPM_ratio_GTn_GGn']])
plt.show()

# %%
# Save df as cleaned csv
numeric_cols = df.columns[1:]  # exclude index
df[numeric_cols] = df[numeric_cols].round(2)

# Save to CSV again
df.to_csv("turbine_data_cleaned.csv", index=False)
print("turbine_data_cleaned.csv created successfully")
# Out:
# turbine_data_cleaned.csv created successfully

# %%
import pandas as pd

df = pd.read_csv("turbine_data_cleaned.csv")

# Rename columns to match SQL schema
df.rename(columns={
    "index": "id",  # optional if you don't want to keep CSV index
    "Lever position (Lp)": "lp",
    "Ship speed (V) [knots]": "v",
    "Gas Turbine shaft torque (GTT) [kN/m]": "gtt",
    "Gas Turbine revolutions (GTn) [rpm]": "gtn",
    "Gas Generator revolutions (GGn) [rpm]": "ggn",
    "Starboard Propeller Torque (Ts) [kN/m]": "ts",
    "Port Propeller Torque (Tp) [kN/m]": "tp",
    "HP Turbine exit temperature (T48) [°C]": "t48",
    "Compressor inlet air temperature (T1) [°C]": "t1",
    "Compressor outlet air temperature (T2) [°C]": "t2",
    "HP Turbine exit pressure (P48) [bar]": "p48",
    "Compressor inlet air pressure (P1) [bar]": "p1",
    "Compressor outlet air pressure (P2) [bar]": "p2",
    "Exhaust gas pressure [bar]": "pexh",
    "Turbine Injection Control (TIC) [%]": "tic",
    "Fuel flow (mf) [kg/s]": "mf",
    "Compressor decay coefficient": "decay_coeff_comp",
    "Turbine decay coefficient": "decay_coeff_turbine",
    "Temp_ratio_T48_P48": "temp_ratio_t48_p48",
    "Temp_ratio_T1_P1": "temp_ratio_t1_p1",
    "Temp_ratio_T2_P2": "temp_ratio_t2_p2",
    "Torque_diff": "torque_diff",
    "RPM_ratio_GTn_GGn": "rpm_ratio_gtn_ggn",
    "Fuel_per_RPM": "fuel_per_rpm",
    "Total_Prop_Torque": "total_prop_torque",
    "Power_Proxy_kW": "power_proxy_kw",
    "Total_decay_score": "total_decay_score"
}, inplace=True)

# Save the renamed DataFrame to a new CSV (or overwrite existing one)
df.to_csv("turbine_data_renamed.csv", index=False)
print("turbine_data_renamed.csv created successfully")
# Out:
# turbine_data_renamed.csv created successfully

# %%
import pandas as pd

# Load the renamed CSV
df = pd.read_csv("turbine_data_renamed.csv")

# Drop Temp_ratio columns
columns_to_drop = [
    "temp_ratio_t48_p48",
    "temp_ratio_t1_p1",
    "temp_ratio_t2_p2",
    "torque_diff","rpm_ratio_gtn_ggn","fuel_per_rpm","total_prop_torque",
    "power_proxy_kw",
    "total_decay_score"
    
]

df.drop(columns=columns_to_drop, inplace=True)

# Save to new CSV
df.to_csv("turbine_data_silver_level.csv", index=False)
print("turbine_data_silver_level.csv created successfully")
# Out:
# turbine_data_silver_level.csv created successfully

# %% [markdown]
# # <center>SQL & Exploratory Analysis</center>

# %% [markdown]
# #### SQL Table Creation

# %%
#SQlite database connection

import sqlite3
import pandas as pd
from sqlalchemy import create_engine

# Option 1: Using sqlite3 directly
conn = sqlite3.connect("turbine_data.db")  # Creates DB file locally
cursor = conn.cursor()

# %% [markdown]
# #### turbine_metadata, sensor_reading Table schema

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect("turbine_data.db")
cursor = conn.cursor()

# Drop tables if they exist to start fresh
cursor.execute("DROP TABLE IF EXISTS sensor_readings;")
cursor.execute("DROP TABLE IF EXISTS turbine_metadata;")

conn.commit()

# Create the turbine_metadata table first, as it's the referenced table
create_metadata_table_query = """
CREATE TABLE turbine_metadata (
    turbine_id INTEGER PRIMARY KEY,
    location TEXT,
    manufacturer TEXT,
    model TEXT
);
"""
cursor.execute(create_metadata_table_query)
conn.commit()
print("Table 'turbine_metadata' created successfully.\n")

# Create the sensor_readings table with the foreign key constraint
create_sensor_readings_table_query = """
CREATE TABLE sensor_readings (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    timestamp TEXT,
    lp FLOAT,
    v FLOAT,
    gtt FLOAT,
    gtn FLOAT,
    ggn FLOAT,
    ts FLOAT,
    tp FLOAT,
    t48 FLOAT,
    t1 FLOAT,
    t2 FLOAT,
    p48 FLOAT,
    p1 FLOAT,
    p2 FLOAT,
    pexh FLOAT,
    tic FLOAT,
    mf FLOAT,
    decay_coeff_comp FLOAT,
    decay_coeff_turbine FLOAT,
    turbine_id INTEGER,
    FOREIGN KEY (turbine_id) REFERENCES turbine_metadata(turbine_id)
);
"""
cursor.execute(create_sensor_readings_table_query)
conn.commit()
print("Table 'sensor_readings' created successfully with foreign key.\n")

# List all tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)

# Show schema of a specific table
cursor.execute("PRAGMA table_info(sensor_readings);")
schema = cursor.fetchall()
print("\nSchema for sensor_readings:\n")
print("(cid, column_name, data_type, not_null, default_value, primary_key)")
for column in schema:
    print(column)

conn.close()
# Out:
# Table 'turbine_metadata' created successfully.
#
# Table 'sensor_readings' created successfully with foreign key.
#
# Tables: [('sqlite_sequence',), ('users',), ('alerts',), ('turbine_metadata',), ('sensor_readings',)]
#
# Schema for sensor_readings:
#
# (cid, column_name, data_type, not_null, default_value, primary_key)
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'timestamp', 'TEXT', 0, None, 0)
# (2, 'lp', 'FLOAT', 0, None, 0)
# (3, 'v', 'FLOAT', 0, None, 0)
# (4, 'gtt', 'FLOAT', 0, None, 0)
# (5, 'gtn', 'FLOAT', 0, None, 0)
# (6, 'ggn', 'FLOAT', 0, None, 0)
# (7, 'ts', 'FLOAT', 0, None, 0)
# (8, 'tp', 'FLOAT', 0, None, 0)
# (9, 't48', 'FLOAT', 0, None, 0)
# (10, 't1', 'FLOAT', 0, None, 0)
# (11, 't2', 'FLOAT', 0, None, 0)
# (12, 'p48', 'FLOAT', 0, None, 0)
# (13, 'p1', 'FLOAT', 0, None, 0)
# (14, 'p2', 'FLOAT', 0, None, 0)
# (15, 'pexh', 'FLOAT', 0, None, 0)
# (16, 'tic', 'FLOAT', 0, None, 0)
# (17, 'mf', 'FLOAT', 0, None, 0)
# (18, 'decay_coeff_comp', 'FLOAT', 0, None, 0)
# (19, 'decay_coeff_turbine', 'FLOAT', 0, None, 0)
# (20, 'turbine_id', 'INTEGER', 0, None, 0)

# %% [markdown]
# #### turbine_metadata table schema

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect("turbine_data.db")
cursor = conn.cursor()
cursor.execute("DROP TABLE IF EXISTS turbine_metadata;")
conn.commit()
# Create turbine_metadata table
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='turbine_metadata';")
if cursor.fetchone():
    print("Table 'turbine_metadata' already exists.")
else:
    create_metadata_query = """
    CREATE TABLE turbine_metadata (
        turbine_id INTEGER PRIMARY KEY,
        location TEXT,
        manufacturer TEXT,
        model TEXT,
        install_date DATE
    );
    """
    cursor.execute(create_metadata_query)
    conn.commit()
    print("Table 'turbine_metadata' created successfully.")



# List all tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)

# Show schema of a specific table
cursor.execute("PRAGMA table_info(turbine_metadata);")
schema = cursor.fetchall()
print("\nSchema for turbine_metadata:\n")
print("(cid, column_name, data_type, not_null, default_value, primary_key)")
for column in schema:
    print(column)

conn.close()
# Out:
# Table 'turbine_metadata' created successfully.
# Tables: [('sqlite_sequence',), ('users',), ('alerts',), ('sensor_readings',), ('turbine_metadata',)]
#
# Schema for turbine_metadata:
#
# (cid, column_name, data_type, not_null, default_value, primary_key)
# (0, 'turbine_id', 'INTEGER', 0, None, 1)
# (1, 'location', 'TEXT', 0, None, 0)
# (2, 'manufacturer', 'TEXT', 0, None, 0)
# (3, 'model', 'TEXT', 0, None, 0)
# (4, 'install_date', 'DATE', 0, None, 0)

# %% [markdown]
# #### alert table schema

# %%
import sqlite3

conn = sqlite3.connect("turbine_data.db")
cursor = conn.cursor()

# Drop alerts table if it exists
cursor.execute("DROP TABLE IF EXISTS alerts;")
print("Existing 'alerts' table dropped (if it existed).")

# Create alerts table
create_alerts_query = """
CREATE TABLE alerts (
    alert_id INTEGER PRIMARY KEY AUTOINCREMENT,
    turbine_id INTEGER,
    timestamp TEXT,
    metric TEXT,
    alert_type TEXT,
    severity TEXT,
    actual_value FLOAT,
    threshold_value FLOAT,
    description TEXT,
    FOREIGN KEY (turbine_id) REFERENCES turbine_metadata(turbine_id)
);
"""
cursor.execute(create_alerts_query)
conn.commit()
print("Table 'alerts' created successfully.")

# List all tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)

# Show schema of alerts table
cursor.execute("PRAGMA table_info(alerts);")
schema = cursor.fetchall()
print("\nSchema for alerts:\n")
print("(cid, column_name, data_type, not_null, default_value, primary_key)")
for column in schema:
    print(column)

conn.close()
# Out:
# Existing 'alerts' table dropped (if it existed).
# Table 'alerts' created successfully.
# Tables: [('sqlite_sequence',), ('users',), ('sensor_readings',), ('turbine_metadata',), ('alerts',)]
#
# Schema for alerts:
#
# (cid, column_name, data_type, not_null, default_value, primary_key)
# (0, 'alert_id', 'INTEGER', 0, None, 1)
# (1, 'turbine_id', 'INTEGER', 0, None, 0)
# (2, 'timestamp', 'TEXT', 0, None, 0)
# (3, 'metric', 'TEXT', 0, None, 0)
# (4, 'alert_type', 'TEXT', 0, None, 0)
# (5, 'severity', 'TEXT', 0, None, 0)
# (6, 'actual_value', 'FLOAT', 0, None, 0)
# (7, 'threshold_value', 'FLOAT', 0, None, 0)
# (8, 'description', 'TEXT', 0, None, 0)

# %% [markdown]
# #### Insert sensor_reading table values

# %%
import pandas as pd
import sqlite3
from datetime import datetime, timedelta

# --- 1. Data Loading and Preparation ---
# Load the CSV
try:
    df = pd.read_csv("turbine_data_renamed.csv")
except FileNotFoundError:
    print("Error: The file 'turbine_data_renamed.csv' was not found.")
    exit()

# Select the columns needed for the database table
# Ensure the columns in this list match your CSV and the desired table schema
raw_columns = [
    "lp","v","gtt","gtn","ggn","ts","tp","t48","t1","t2",
    "p48","p1","p2","pexh","tic","mf","decay_coeff_comp","decay_coeff_turbine"
]
df_raw = df[raw_columns].copy()

# Generate incremental timestamps
start_time = datetime(2025, 9, 21, 10, 0, 0)
time_interval = timedelta(seconds=10)
df_raw['timestamp'] = [(start_time + i*time_interval).strftime("%Y-%m-%d %H:%M:%S")
                         for i in range(len(df_raw))]

# Add the 'turbine_id' column with a value of 1 for all rows
df_raw['turbine_id'] = 1

# Reorder columns to match SQLite schema: timestamp first
ordered_columns = [
    "timestamp","lp","v","gtt","gtn","ggn","ts","tp","t48","t1","t2",
    "p48","p1","p2","pexh","tic","mf","decay_coeff_comp","decay_coeff_turbine",
    "turbine_id"
]
df_raw = df_raw[ordered_columns]

# --- 2. Database Connection and Table Creation ---
conn = sqlite3.connect("turbine_data.db")
cursor = conn.cursor()

# Drop the table if it already exists to ensure a clean start
cursor.execute("DROP TABLE IF EXISTS sensor_readings;")
conn.commit()

# Create the table with all the necessary columns, including turbine_id
create_table_query = """
CREATE TABLE sensor_readings (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    timestamp TEXT,
    lp FLOAT,
    v FLOAT,
    gtt FLOAT,
    gtn FLOAT,
    ggn FLOAT,
    ts FLOAT,
    tp FLOAT,
    t48 FLOAT,
    t1 FLOAT,
    t2 FLOAT,
    p48 FLOAT,
    p1 FLOAT,
    p2 FLOAT,
    pexh FLOAT,
    tic FLOAT,
    mf FLOAT,
    decay_coeff_comp FLOAT,
    decay_coeff_turbine FLOAT,
    turbine_id INTEGER
);
"""
cursor.execute(create_table_query)
conn.commit()
print("Table 'sensor_readings' created successfully.\n")

# --- 3. Data Insertion ---
# Use pandas to_sql to insert the DataFrame into the table
df_raw.to_sql("sensor_readings", conn, if_exists="append", index=False)

print(f"{len(df_raw)} rows inserted into 'sensor_readings' table.\n")

# --- 4. Verification ---
# Preview the first 5 rows to confirm correct insertion
query = "SELECT * FROM sensor_readings LIMIT 5;"
df_preview = pd.read_sql(query, conn)
print(df_preview)

conn.close()
# Out:
# Table 'sensor_readings' created successfully.
#
# 11934 rows inserted into 'sensor_readings' table.
#
#    id            timestamp    lp     v       gtt      gtn      ggn      ts  \
# 0   1  2025-09-21 10:00:00  1.14   3.0    289.96  1349.49  6677.38    7.58
# 1   2  2025-09-21 10:00:10  1.61   4.5   3625.07  1362.83  6752.92   17.89
# 2   3  2025-09-21 10:00:20  2.12   6.0   5209.79  1370.80  6872.55   32.05
# 3   4  2025-09-21 10:00:30  3.13   9.0  10021.27  1436.80  7244.30   67.45
# 4   5  2025-09-21 10:00:40  4.15  12.0  14913.35  1619.51  7799.74  116.48
#
#        tp     t48     t1      t2   p48   p1    p2  pexh    tic    mf  \
# 0    7.58  464.01  288.0  550.56  1.10  1.0  5.95  1.02   7.14  0.08
# 1   17.89  549.70  288.0  566.11  1.21  1.0  6.61  1.02   8.90  0.18
# 2   32.05  568.47  288.0  573.27  1.27  1.0  6.93  1.02  10.29  0.21
# 3   67.45  634.29  288.0  594.37  1.46  1.0  7.95  1.02  13.95  0.30
# 4  116.48  666.32  288.0  615.69  1.71  1.0  9.26  1.02  19.19  0.38
#
#    decay_coeff_comp  decay_coeff_turbine  turbine_id
# 0              0.95                 0.98           1
# 1              0.95                 0.98           1
# 2              0.95                 0.98           1
# 3              0.95                 0.98           1
# 4              0.95                 0.98           1

# %% [markdown]
# #### Insert turbine_metadata table values

# %%
import sqlite3
from datetime import datetime

# Connect to SQLite
conn = sqlite3.connect("turbine_data.db")
cursor = conn.cursor()

# Example turbine metadata
turbine_data = [
    (1, "Singapore Port", "GE", "GTX-1000", "2023-01-15"),
    (2, "Singapore Port", "Siemens", "ST-2000", "2022-08-10"),
    (3, "Singapore Port", "Rolls-Royce", "RR-Turbo", "2024-03-05")
]

# Insert into turbine_metadata table
insert_query = """
INSERT OR IGNORE INTO turbine_metadata
(turbine_id, location, manufacturer, model, install_date)
VALUES (?, ?, ?, ?, ?)
"""

cursor.executemany(insert_query, turbine_data)
conn.commit()
print("(turbine_id, location, manufacturer, model, install_date)")
# Verify insertion
cursor.execute("SELECT * FROM turbine_metadata;")
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close connection
conn.close()
# Out:
# (turbine_id, location, manufacturer, model, install_date)
# (1, 'Singapore Port', 'GE', 'GTX-1000', '2023-01-15')
# (2, 'Singapore Port', 'Siemens', 'ST-2000', '2022-08-10')
# (3, 'Singapore Port', 'Rolls-Royce', 'RR-Turbo', '2024-03-05')

# %% [markdown]
# #### Insert Alert table values

# %%
import sqlite3
from datetime import datetime

# Connect to SQLite
conn = sqlite3.connect("turbine_data.db")
cursor = conn.cursor()

# Fetch sensor readings
query = "SELECT rowid, timestamp, ts, tp, t48, mf, turbine_id FROM sensor_readings;"
cursor.execute(query)
rows = cursor.fetchall()

alerts_to_insert = []

# Define thresholds (with warning/critical if needed)
THRESHOLDS = {
    "t48": {"warning": 550, "critical": 600},      
    "mf": {"warning": 0.2, "critical": 0.3},       
    "ts": {"warning": 40, "critical": 50},         
    "tp": {"warning": 40, "critical": 50}          
}

# Generate alerts
for row in rows:
    sensor_id, timestamp, ts, tp, t48, mf, turbine_id = row

    # T48
    if t48 > THRESHOLDS["t48"]["critical"]:
        severity = "Critical"
    elif t48 > THRESHOLDS["t48"]["warning"]:
        severity = "Warning"
    else:
        severity = None

    if severity:
        alerts_to_insert.append((
            turbine_id, timestamp, "t48", "Overheat", severity, t48, THRESHOLDS["t48"]["critical"],
            f"T48={t48}°C exceeds threshold"
        ))

    # Fuel Flow
    if mf > THRESHOLDS["mf"]["critical"]:
        severity = "Critical"
    elif mf > THRESHOLDS["mf"]["warning"]:
        severity = "Warning"
    else:
        severity = None

    if severity:
        alerts_to_insert.append((
            turbine_id, timestamp, "mf", "High Fuel Flow", severity, mf, THRESHOLDS["mf"]["critical"],
            f"mf={mf} kg/s exceeds threshold"
        ))

    # Propeller Torque (ts and tp)
    for metric, value in [("ts", ts), ("tp", tp)]:
        if value > THRESHOLDS[metric]["critical"]:
            severity = "Critical"
        elif value > THRESHOLDS[metric]["warning"]:
            severity = "Warning"
        else:
            severity = None

        if severity:
            alerts_to_insert.append((
                turbine_id, timestamp, metric, "High Propeller Torque", severity, value, THRESHOLDS[metric]["critical"],
                f"{metric}={value} exceeds threshold"
            ))

# Insert alerts
insert_query = """
INSERT INTO alerts (
    turbine_id, timestamp, metric, alert_type, severity, actual_value, threshold_value, description
) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
"""
cursor.executemany(insert_query, alerts_to_insert)
conn.commit()

print(f"{len(alerts_to_insert)} alerts inserted into 'alerts' table.\n")

# Verify first 5 alerts
cursor.execute("SELECT * FROM alerts LIMIT 5;")
print("(alert_id, turbine_id, timestamp, metric, alert_type, severity, actual_value, threshold_value, description)")
for alert in cursor.fetchall():
    print(alert)

conn.close()
# Out:
# 43900 alerts inserted into 'alerts' table.
#
# (alert_id, turbine_id, timestamp, metric, alert_type, severity, actual_value, threshold_value, description)
# (1, 1, '2025-09-21 10:00:20', 't48', 'Overheat', 'Warning', 568.47, 600.0, 'T48=568.47°C exceeds threshold')
# (2, 1, '2025-09-21 10:00:20', 'mf', 'High Fuel Flow', 'Warning', 0.21, 0.3, 'mf=0.21 kg/s exceeds threshold')
# (3, 1, '2025-09-21 10:00:30', 't48', 'Overheat', 'Critical', 634.29, 600.0, 'T48=634.29°C exceeds threshold')
# (4, 1, '2025-09-21 10:00:30', 'mf', 'High Fuel Flow', 'Warning', 0.3, 0.3, 'mf=0.3 kg/s exceeds threshold')
# (5, 1, '2025-09-21 10:00:30', 'ts', 'High Propeller Torque', 'Critical', 67.45, 50.0, 'ts=67.45 exceeds threshold')

# %% [markdown]
# ## SQL Transformations (Joins, Filters, Aggregations)

# %% [markdown]
# #### Joins

# %%
# Load extension of ipython-sql
# %load_ext sql
# connect to sqlite
# %sql sqlite:///turbine_data.db
# %config SqlMagic.style = 'PLAIN_COLUMNS'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.autocommit = True
# %config SqlMagic.autopandas = True

# %%
import pandas as pd
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('turbine_data.db')

# Define your SQL query
query = """
SELECT
    s.id,
    s.timestamp,
    s.lp,
    s.v,
    s.gtt,
    s.gtn,
    s.ggn,
    s.ts,
    s.tp,
    s.t48,
    s.mf,
    t.location,
    t.manufacturer,
    t.model
FROM sensor_readings AS s
JOIN turbine_metadata AS t
ON s.turbine_id = t.turbine_id
WHERE s.turbine_id = 1;
"""

# Execute the query and load results into a Pandas DataFrame
df_result = pd.read_sql(query, conn)

# Print the resulting DataFrame
print(df_result)

# Close the database connection
conn.close()
# Out:
#           id            timestamp    lp     v       gtt      gtn      ggn  \
# 0          1  2025-09-21 10:00:00  1.14   3.0    289.96  1349.49  6677.38
# 1          2  2025-09-21 10:00:10  1.61   4.5   3625.07  1362.83  6752.92
# 2          3  2025-09-21 10:00:20  2.12   6.0   5209.79  1370.80  6872.55
# 3          4  2025-09-21 10:00:30  3.13   9.0  10021.27  1436.80  7244.30
# 4          5  2025-09-21 10:00:40  4.15  12.0  14913.35  1619.51  7799.74
# ...      ...                  ...   ...   ...       ...      ...      ...
# 11929  11930  2025-09-22 19:08:10  4.15  12.0  14906.30  1619.51  7754.30
# 11930  11931  2025-09-22 19:08:20  5.16  15.0  22035.49  1926.18  8333.33
# 11931  11932  2025-09-22 19:08:30  6.15  18.0  30130.67  2303.05  8797.08
# 11932  11933  2025-09-22 19:08:40  7.18  21.0  39919.89  2690.74  9073.84
# 11933  11934  2025-09-22 19:08:50  8.22  24.0  54257.19  3108.63  9388.04
#
#            ts      tp     t48    mf        location manufacturer     model
# 0        7.58    7.58  464.01  0.08  Singapore Port           GE  GTX-1000
# 1       17.89   17.89  549.70  0.18  Singapore Port           GE  GTX-1000
# 2       32.05   32.05  568.47  0.21  Singapore Port           GE  GTX-1000
# 3       67.45   67.45  634.29  0.30  Singapore Port           GE  GTX-1000
# 4      116.48  116.48  666.32  0.38  Singapore Port           GE  GTX-1000
# ...       ...     ...     ...   ...             ...          ...       ...
# 11929  116.43  116.43  620.92  0.34  Singapore Port           GE  GTX-1000
# 11930  178.31  178.31  682.10  0.48  Singapore Port           GE  GTX-1000
# 11931  251.19  251.19  741.84  0.65  Singapore Port           GE  GTX-1000
# 11932  338.79  338.79  812.27  0.88  Singapore Port           GE  GTX-1000
# 11933  471.76  471.76  909.27  1.23  Singapore Port           GE  GTX-1000
#
# [11934 rows x 14 columns]

# %% [markdown]
# #### Filter Data

# %%
# %config SqlMagic.style = 'PLAIN_GRID'

# %%
import sqlite3
import pandas as pd

# Connect to SQLite
conn = sqlite3.connect("turbine_data.db")

# Query 1: Fuel flow > 0.3
df1 = pd.read_sql("SELECT * FROM sensor_readings WHERE mf > 0.3;", conn)

# Query 2: Time range filter
df2 = pd.read_sql("""
    SELECT * 
    FROM sensor_readings
    WHERE timestamp BETWEEN '2025-09-21 10:00:00' AND '2025-09-21 10:00:30';
""", conn)

# Show preview
print("Show all records where mf > 0.3")
print(df1.head())
print("="*100)
print("\nShow all records where timestamp BETWEEN '2025-09-21 10:00:00' AND '2025-09-21 10:00:30")
print(df2.head())

conn.close()
# Out:
# Show all records where mf > 0.3
#    id            timestamp    lp     v       gtt      gtn      ggn      ts  \
# 0   5  2025-09-21 10:00:40  4.15  12.0  14913.35  1619.51  7799.74  116.48
# 1   6  2025-09-21 10:00:50  5.16  15.0  22051.19  1926.39  8371.92  178.45
# 2   7  2025-09-21 10:01:00  6.15  18.0  30137.11  2303.27  8818.52  251.22
# 3   8  2025-09-21 10:01:10  7.18  21.0  39923.91  2691.02  9093.12  338.78
# 4   9  2025-09-21 10:01:20  8.22  24.0  54247.44  3108.68  9409.84  471.66
#
#        tp     t48     t1      t2   p48   p1     p2  pexh    tic    mf  \
# 0  116.48  666.32  288.0  615.69  1.71  1.0   9.26  1.02  19.19  0.38
# 1  178.45  731.13  288.0  645.30  2.08  1.0  11.19  1.03  26.75  0.53
# 2  251.22  795.56  288.0  674.00  2.51  1.0  13.41  1.03  36.00  0.71
# 3  338.78  869.10  288.0  706.04  3.01  1.0  15.89  1.03  48.03  0.95
# 4  471.66  974.22  288.0  743.61  3.68  1.0  19.04  1.04  66.40  1.33
#
#    decay_coeff_comp  decay_coeff_turbine  turbine_id
# 0              0.95                 0.98           1
# 1              0.95                 0.98           1
# 2              0.95                 0.98           1
# 3              0.95                 0.98           1
# 4              0.95                 0.98           1
# ====================================================================================================
#
# Show all records where timestamp BETWEEN '2025-09-21 10:00:00' AND '2025-09-21 10:00:30
#    id            timestamp    lp    v       gtt      gtn      ggn     ts  \
# 0   1  2025-09-21 10:00:00  1.14  3.0    289.96  1349.49  6677.38   7.58
# 1   2  2025-09-21 10:00:10  1.61  4.5   3625.07  1362.83  6752.92  17.89
# 2   3  2025-09-21 10:00:20  2.12  6.0   5209.79  1370.80  6872.55  32.05
# 3   4  2025-09-21 10:00:30  3.13  9.0  10021.27  1436.80  7244.30  67.45
#
#       tp     t48     t1      t2   p48   p1    p2  pexh    tic    mf  \
# 0   7.58  464.01  288.0  550.56  1.10  1.0  5.95  1.02   7.14  0.08
# 1  17.89  549.70  288.0  566.11  1.21  1.0  6.61  1.02   8.90  0.18
# 2  32.05  568.47  288.0  573.27  1.27  1.0  6.93  1.02  10.29  0.21
# 3  67.45  634.29  288.0  594.37  1.46  1.0  7.95  1.02  13.95  0.30
#
#    decay_coeff_comp  decay_coeff_turbine  turbine_id
# 0              0.95                 0.98           1
# 1              0.95                 0.98           1
# 2              0.95                 0.98           1
# 3              0.95                 0.98           1

# %% [markdown]
# #### Aggregations

# %% [markdown]
# #### Fuel usage over time (hourly)

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# Connect to database
conn = sqlite3.connect("turbine_data.db")

# Aggregated fuel usage by hour
df1 = pd.read_sql("""
    SELECT 
        strftime('%Y-%m-%d %H', timestamp) AS hour,
        AVG(mf) AS avg_fuel_flow,
        SUM(mf) AS total_fuel
    FROM sensor_readings
    GROUP BY hour
    ORDER BY hour;
""", conn)

# Preview
print(df1.head())

conn.close()


# Convert hour to datetime
df1['hour'] = pd.to_datetime(df1['hour'])

# Plot total fuel over time
plt.figure(figsize=(12,5))
sns.lineplot(data=df1, x='hour', y='total_fuel', marker='o')
plt.title("Total Fuel Flow Over Time")
plt.xlabel("Hour")
plt.ylabel("Total Fuel (kg/s)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
#             hour  avg_fuel_flow  total_fuel
# 0  2025-09-21 10       0.680250      244.89
# 1  2025-09-21 11       0.675222      243.08
# 2  2025-09-21 12       0.680222      244.88
# 3  2025-09-21 13       0.672389      242.06
# 4  2025-09-21 14       0.675722      243.26

# %% [markdown]
# #### Turbine efficiency proxy

# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect("turbine_data.db")

# Compute turbine efficiency proxy
df_efficiency = pd.read_sql("""
    SELECT 
        timestamp,
        ((ts + tp) * gtn / mf) AS efficiency_proxy
    FROM sensor_readings
    WHERE mf > 0
    ORDER BY timestamp;
""", conn)

# Preview first 5 rows
print(df_efficiency.head())

conn.close()

df_efficiency['timestamp'] = pd.to_datetime(df_efficiency['timestamp'])

# Plot efficiency proxy
plt.figure(figsize=(12,5))
sns.lineplot(data=df_efficiency, x='timestamp', y='efficiency_proxy')
plt.title("Turbine Efficiency Proxy Over Time")
plt.xlabel("Timestamp")
plt.ylabel("Efficiency Proxy (kW per kg/s)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
#              timestamp  efficiency_proxy
# 0  2025-09-21 10:00:00     255728.355000
# 1  2025-09-21 10:00:10     270900.318889
# 2  2025-09-21 10:00:20     418420.380952
# 3  2025-09-21 10:00:30     646081.066667
# 4  2025-09-21 10:00:40     992844.867368

# %% [markdown]
# #### Alerts per turbine

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# Connect to SQLite database
conn = sqlite3.connect("turbine_data.db")

# Total number of alerts
df_total_alert = pd.read_sql("""
    SELECT COUNT(*) AS total_alerts
    FROM alerts;
""", conn)

# Alerts count per turbine and alert type
df_efficiency = pd.read_sql("""
    SELECT turbine_id, alert_type, severity, COUNT(*) AS alert_count
    FROM alerts
    GROUP BY turbine_id, alert_type, severity
    ORDER BY turbine_id, alert_type, severity;
""", conn)

# Corrected query: Top 5 most frequent alert types
df_top_alerts = pd.read_sql("""
    SELECT alert_type, COUNT(*) AS alert_count
    FROM alerts
    GROUP BY alert_type
    ORDER BY alert_count DESC
    LIMIT 5;
""", conn)

conn.close()

# Print summaries
print("Total Alerts:")
print(df_total_alert)
print("\nAlerts per Turbine and Alert Type:")
print(df_efficiency.head())
print("\nTop 5 Alert Types:")
print(df_top_alerts)

# Plot: Alerts per turbine by alert type and severity
plt.figure(figsize=(12,6))
sns.barplot(
    data=df_efficiency,
    x='turbine_id',
    y='alert_count',
    hue='severity',
    palette='viridis'
)
plt.title("Alert Counts per Turbine by Severity")
plt.xlabel("Turbine ID")
plt.ylabel("Number of Alerts")
plt.legend(title="Severity")
plt.show()

# Corrected plot: Top 5 alert types plot
plt.figure(figsize=(8,4))
sns.barplot(
    data=df_top_alerts,
    x='alert_type',
    y='alert_count',
    hue='alert_type', # Fix: Pass the 'x' variable to 'hue'
    palette='coolwarm',
    legend=False # Fix: Set legend to False
)
plt.title("Top 5 Alert Types")
plt.xlabel("Alert Type")
plt.ylabel("Number of Alerts")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Total Alerts:
#    total_alerts
# 0         43900
#
# Alerts per Turbine and Alert Type:
#    turbine_id             alert_type  severity  alert_count
# 0           1         High Fuel Flow  Critical         9280
# 1           1         High Fuel Flow   Warning         1992
# 2           1  High Propeller Torque  Critical        21212
# 3           1               Overheat  Critical         9643
# 4           1               Overheat   Warning         1773
#
# Top 5 Alert Types:
#               alert_type  alert_count
# 0  High Propeller Torque        21212
# 1               Overheat        11416
# 2         High Fuel Flow        11272

# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect("turbine_data.db")
df_total_alert = pd.read_sql(
    """
    SELECT *
FROM sensor_readings;

    """
,conn)

# Compute turbine efficiency proxy
df_efficiency = pd.read_sql("""
   SELECT * from turbine_metadata

""", conn)

df1 = pd.read_sql("""
   SELECT * from alerts

""", conn)
print(df_total_alert.tail(6))
print("\n")
# Preview first 5 rows
print(df_efficiency.tail())
print(df1.tail())
# Out:
#           id            timestamp     lp     v       gtt      gtn       ggn  \
# 11933  11934  2025-09-22 19:08:50   8.22  24.0  54257.19  3108.63   9388.04
# 11934  11935      9/22/2025 19:09   9.15  27.0  67890.12  3501.22   9600.45
# 11935  11936      9/22/2025 19:09  10.22  30.0  74567.89  3902.33   9901.22
# 11936  11937      9/22/2025 19:09  11.05  33.0  80123.55  4200.44  10120.33
# 11937  11938      9/22/2025 19:09  12.10  36.0  86000.90  4500.55  10300.88
# 11938  11939      9/22/2025 19:09  13.22  39.0  92011.45  4802.22  10512.99
#
#            ts      tp      t48  ...      t2   p48   p1     p2  pexh     tic  \
# 11933  471.76  471.76   909.27  ...  723.34  3.70  1.0  18.73  1.04   62.08
# 11934  512.12  512.12  1020.44  ...  760.88  4.21  2.0  21.55  1.05   80.45
# 11935  560.22  560.22  1101.56  ...  790.66  4.88  2.0  23.60  1.06   95.32
# 11936  590.18  590.18  1165.33  ...  820.11  5.11  2.0  25.90  1.07  110.25
# 11937  620.14  620.14  1222.44  ...  840.77  5.56  2.0  28.33  1.08  128.10
# 11938  650.09  650.09  1290.66  ...  860.55  6.02  2.0  30.88  1.09  140.22
#
#          mf  decay_coeff_comp  decay_coeff_turbine  turbine_id
# 11933  1.23               1.0                  1.0           1
# 11934  1.55               1.0                  1.0           1
# 11935  1.72               1.0                  1.0           1
# 11936  1.88               1.0                  1.0           1
# 11937  2.05               1.0                  1.0           1
# 11938  2.25               1.0                  1.0           1
#
# [6 rows x 21 columns]
#
#
#    turbine_id         location manufacturer     model install_date
# 1           2   Singapore Port      Siemens   ST-2000   2022-08-10
# 2           3   Singapore Port  Rolls-Royce  RR-Turbo   2024-03-05
# 3           4  Chennai Harbour           GE  GTX-2000   2023-07-20
# 4           5  Mumbai Dockyard      Siemens   ST-3000   2021-11-11
# 5           6  Chennai Harbour        Volvo       GTA   2002-01-01
#        alert_id  turbine_id                   timestamp metric  \
# 43901     43902           1  2025-09-22T15:49:10.658437    t48
# 43902     43903           1  2025-09-22T15:53:15.022108    t48
# 43903     43904           1  2025-09-22T17:07:23.019810     tp
# 43904     43905           1  2025-09-22T18:20:32.494078    t48
# 43905     43906           1  2025-09-23T19:01:53.159947     ts
#
#                   alert_type   severity  actual_value  threshold_value  \
# 43901               Overheat   Critical         800.0            600.0
# 43902               Overheat   Critical         800.0            600.0
# 43903  High Propeller Torque    Warning          40.0             50.0
# 43904               Overheat    Warning         580.0            600.0
# 43905  High Propeller torque  Critical!          60.0             50.0
#
#                        description
# 43901  T48=800°C exceeds threshold
# 43902  T48=800°C exceeds threshold
# 43903    tp=40 close to threshold
# 43904            t48- 580 overheat
# 43905                high ts value
